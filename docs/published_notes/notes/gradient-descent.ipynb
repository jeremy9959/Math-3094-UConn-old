# %% [markdown]
# # Surface

# %%
import matplotlib.pylab as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x = y = np.linspace(-3,3,100)
X, Y = np.meshgrid(x, y)
Z = X**4+Y**4-16*X*Y
ax.plot_surface(X, Y, Z)
ax.set_zlim3d(0,120)
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_zlabel('Z Axis')
plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
def E(u,v):
    return u**4+v**4-16*u*v

eta=0.01
x=1.2; y=1.2
print (0,'\t','x=', x,'\t','y=',y,'\t', 'E=',E(x,y))
for i in range(0,30):
	g=4*x**3-16*y
	h=4*y**3-16*x
	x=x-eta*g
	y=y-eta*h
	print (i+1,'\t','x=',round(x,3),'\t','y=',round(y,3),'\t','E=',round(E(x,y),3))
# Out:
# 0 	 x= 1.2 	 y= 1.2 	 E= -18.8928
# 1 	 x= 1.323 	 y= 1.323 	 E= -21.875
# 2 	 x= 1.442 	 y= 1.442 	 E= -24.621
# 3 	 x= 1.553 	 y= 1.553 	 E= -26.95
# 4 	 x= 1.651 	 y= 1.651 	 E= -28.76
# 5 	 x= 1.735 	 y= 1.735 	 E= -30.048
# 6 	 x= 1.804 	 y= 1.804 	 E= -30.889
# 7 	 x= 1.858 	 y= 1.858 	 E= -31.399
# 8 	 x= 1.899 	 y= 1.899 	 E= -31.688
# 9 	 x= 1.929 	 y= 1.929 	 E= -31.843
# 10 	 x= 1.95 	 y= 1.95 	 E= -31.923
# 11 	 x= 1.966 	 y= 1.966 	 E= -31.963
# 12 	 x= 1.976 	 y= 1.976 	 E= -31.982
# 13 	 x= 1.984 	 y= 1.984 	 E= -31.992
# 14 	 x= 1.989 	 y= 1.989 	 E= -31.996
# 15 	 x= 1.992 	 y= 1.992 	 E= -31.998
# 16 	 x= 1.995 	 y= 1.995 	 E= -31.999
# 17 	 x= 1.996 	 y= 1.996 	 E= -32.0
# 18 	 x= 1.998 	 y= 1.998 	 E= -32.0
# 19 	 x= 1.998 	 y= 1.998 	 E= -32.0
# 20 	 x= 1.999 	 y= 1.999 	 E= -32.0
# 21 	 x= 1.999 	 y= 1.999 	 E= -32.0
# 22 	 x= 1.999 	 y= 1.999 	 E= -32.0
# 23 	 x= 2.0 	 y= 2.0 	 E= -32.0
# 24 	 x= 2.0 	 y= 2.0 	 E= -32.0
# 25 	 x= 2.0 	 y= 2.0 	 E= -32.0
# 26 	 x= 2.0 	 y= 2.0 	 E= -32.0
# 27 	 x= 2.0 	 y= 2.0 	 E= -32.0
# 28 	 x= 2.0 	 y= 2.0 	 E= -32.0
# 29 	 x= 2.0 	 y= 2.0 	 E= -32.0
# 30 	 x= 2.0 	 y= 2.0 	 E= -32.0

# %% [markdown]
# ## Linear Regression Revisited

# %% [markdown]
# We will redo the example of multivariate-data in linear regression using gradient descent.

# %%
data = np.genfromtxt('multivar_simulated.csv',skip_header=1,delimiter=',')

# %%
Y = data[:,1]
X1 = data[:,2:]

# %%
O = np.ones(shape=(X.shape[0],1))
X = np.concatenate([X1,O],axis=1)
X.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-d8d1c40d2197> in <module>
#       1 O = np.ones(shape=(X.shape[0],1))
# ----> 2 X = np.concatenate([X1,O],axis=1)
#       3 X.shape
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 75 and the array at index 1 has size 100

# %% [markdown]
# The error function is given by
# $$ E = \sum_{j=1}^{N} (y_j-\sum_{s=1}^{k+1} x_{js}m_{s})^2 .$$

# %% [markdown]
# Write a function for $E$.

# %%
#def Er(M):
#    formula here
#    return the result

# %% [markdown]
# The gradient of $E$ is given by
# $$ \nabla E  = -2 X^{\intercal}Y + 2
# X^{\intercal}XM. $$

# %% [markdown]
# Write a function for $\nabla E$.

# %%
#def GE(M):
#    return formula here

# %% [markdown]
# Choose initial values.

# %%
#eta=
#iter_num=
#M=np.array([?,?,?])

# %% [markdown]
# Calculate the initial error.

# %%
Er(M)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-df671a147a5d> in <module>
# ----> 1 Er(M)
#
# NameError: name 'Er' is not defined

# %% [markdown]
# Run a loop for gradient descent and print the values of M and Er(M).

# %%
#Write a loop here
#
#print M and Er(M)

# %% [markdown]
# Compare the result with the previous result from Linear Regression which was
#
# [ 1.78777492, -3.47899986,  6.0608333 ]

# %% [markdown]
# ## Newton's Method

# %%
def E(u,v):
    return u**4+v**4-16*u*v

eta=1
x=1.2; y=1.2
print (0,'\t','x=', x,'\t','y=',y, '\t','E=',E(x,y))
for i in range(0,10):
	d=9*x**2*y**2-16
	g=(3*x**3*y**2 -8*y**3 -16*x)/d
	h=(3*x**2*y**3 -8*x**3 -16*y)/d
	x=x-eta*g
	y=y-eta*h
	print (i+1,'\t','x=', round(x,3),'\t','y=',round(y,3), '\t','E=',round(E(x,y),3))
# Out:
# 0 	 x= 1.2 	 y= 1.2 	 E= -18.8928
# 1 	 x= 10.8 	 y= 10.8 	 E= 25343.539
# 2 	 x= 7.283 	 y= 7.283 	 E= 4778.985
# 3 	 x= 4.981 	 y= 4.981 	 E= 833.891
# 4 	 x= 3.509 	 y= 3.509 	 E= 106.231
# 5 	 x= 2.623 	 y= 2.623 	 E= -15.382
# 6 	 x= 2.169 	 y= 2.169 	 E= -31.005
# 7 	 x= 2.018 	 y= 2.018 	 E= -31.99
# 8 	 x= 2.0 	 y= 2.0 	 E= -32.0
# 9 	 x= 2.0 	 y= 2.0 	 E= -32.0
# 10 	 x= 2.0 	 y= 2.0 	 E= -32.0

# %% [markdown]
# ### Haberman's Survival Data Set
#
# https://archive.ics.uci.edu/ml/datasets/Haberman%27s+Survival

# %%
import numpy as np
import pandas as pd
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("haberman.data",header=None)
X=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

# %%
X
# Out:
# array([[30, 64,  1],
#        [30, 62,  3],
#        [30, 65,  0],
#        [31, 59,  2],
#        [31, 65,  4],
#        [33, 58, 10],
#        [33, 60,  0],
#        [34, 59,  0],
#        [34, 66,  9],
#        [34, 58, 30],
#        [34, 60,  1],
#        [34, 61, 10],
#        [34, 67,  7],
#        [34, 60,  0],
#        [35, 64, 13],
#        [35, 63,  0],
#        [36, 60,  1],
#        [36, 69,  0],
#        [37, 60,  0],
#        [37, 63,  0],
#        [37, 58,  0],
#        [37, 59,  6],
#        [37, 60, 15],
#        [37, 63,  0],
#        [38, 69, 21],
#        [38, 59,  2],
#        [38, 60,  0],
#        [38, 60,  0],
#        [38, 62,  3],
#        [38, 64,  1],
#        [38, 66,  0],
#        [38, 66, 11],
#        [38, 60,  1],
#        [38, 67,  5],
#        [39, 66,  0],
#        [39, 63,  0],
#        [39, 67,  0],
#        [39, 58,  0],
#        [39, 59,  2],
#        [39, 63,  4],
#        [40, 58,  2],
#        [40, 58,  0],
#        [40, 65,  0],
#        [41, 60, 23],
#        [41, 64,  0],
#        [41, 67,  0],
#        [41, 58,  0],
#        [41, 59,  8],
#        [41, 59,  0],
#        [41, 64,  0],
#        [41, 69,  8],
#        [41, 65,  0],
#        [41, 65,  0],
#        [42, 69,  1],
#        [42, 59,  0],
#        [42, 58,  0],
#        [42, 60,  1],
#        [42, 59,  2],
#        [42, 61,  4],
#        [42, 62, 20],
#        [42, 65,  0],
#        [42, 63,  1],
#        [43, 58, 52],
#        [43, 59,  2],
#        [43, 64,  0],
#        [43, 64,  0],
#        [43, 63, 14],
#        [43, 64,  2],
#        [43, 64,  3],
#        [43, 60,  0],
#        [43, 63,  2],
#        [43, 65,  0],
#        [43, 66,  4],
#        [44, 64,  6],
#        [44, 58,  9],
#        [44, 63, 19],
#        [44, 61,  0],
#        [44, 63,  1],
#        [44, 61,  0],
#        [44, 67, 16],
#        [45, 65,  6],
#        [45, 66,  0],
#        [45, 67,  1],
#        [45, 60,  0],
#        [45, 67,  0],
#        [45, 59, 14],
#        [45, 64,  0],
#        [45, 68,  0],
#        [45, 67,  1],
#        [46, 58,  2],
#        [46, 69,  3],
#        [46, 62,  5],
#        [46, 65, 20],
#        [46, 62,  0],
#        [46, 58,  3],
#        [46, 63,  0],
#        [47, 63, 23],
#        [47, 62,  0],
#        [47, 65,  0],
#        [47, 61,  0],
#        [47, 63,  6],
#        [47, 66,  0],
#        [47, 67,  0],
#        [47, 58,  3],
#        [47, 60,  4],
#        [47, 68,  4],
#        [47, 66, 12],
#        [48, 58, 11],
#        [48, 58, 11],
#        [48, 67,  7],
#        [48, 61,  8],
#        [48, 62,  2],
#        [48, 64,  0],
#        [48, 66,  0],
#        [49, 63,  0],
#        [49, 64, 10],
#        [49, 61,  1],
#        [49, 62,  0],
#        [49, 66,  0],
#        [49, 60,  1],
#        [49, 62,  1],
#        [49, 63,  3],
#        [49, 61,  0],
#        [49, 67,  1],
#        [50, 63, 13],
#        [50, 64,  0],
#        [50, 59,  0],
#        [50, 61,  6],
#        [50, 61,  0],
#        [50, 63,  1],
#        [50, 58,  1],
#        [50, 59,  2],
#        [50, 61,  0],
#        [50, 64,  0],
#        [50, 65,  4],
#        [50, 66,  1],
#        [51, 59, 13],
#        [51, 59,  3],
#        [51, 64,  7],
#        [51, 59,  1],
#        [51, 65,  0],
#        [51, 66,  1],
#        [52, 69,  3],
#        [52, 59,  2],
#        [52, 62,  3],
#        [52, 66,  4],
#        [52, 61,  0],
#        [52, 63,  4],
#        [52, 69,  0],
#        [52, 60,  4],
#        [52, 60,  5],
#        [52, 62,  0],
#        [52, 62,  1],
#        [52, 64,  0],
#        [52, 65,  0],
#        [52, 68,  0],
#        [53, 58,  4],
#        [53, 65,  1],
#        [53, 59,  3],
#        [53, 60,  9],
#        [53, 63, 24],
#        [53, 65, 12],
#        [53, 58,  1],
#        [53, 60,  1],
#        [53, 60,  2],
#        [53, 61,  1],
#        [53, 63,  0],
#        [54, 60, 11],
#        [54, 65, 23],
#        [54, 65,  5],
#        [54, 68,  7],
#        [54, 59,  7],
#        [54, 60,  3],
#        [54, 66,  0],
#        [54, 67, 46],
#        [54, 62,  0],
#        [54, 69,  7],
#        [54, 63, 19],
#        [54, 58,  1],
#        [54, 62,  0],
#        [55, 63,  6],
#        [55, 68, 15],
#        [55, 58,  1],
#        [55, 58,  0],
#        [55, 58,  1],
#        [55, 66, 18],
#        [55, 66,  0],
#        [55, 69,  3],
#        [55, 69, 22],
#        [55, 67,  1],
#        [56, 65,  9],
#        [56, 66,  3],
#        [56, 60,  0],
#        [56, 66,  2],
#        [56, 66,  1],
#        [56, 67,  0],
#        [56, 60,  0],
#        [57, 61,  5],
#        [57, 62, 14],
#        [57, 64,  1],
#        [57, 64,  9],
#        [57, 69,  0],
#        [57, 61,  0],
#        [57, 62,  0],
#        [57, 63,  0],
#        [57, 64,  0],
#        [57, 64,  0],
#        [57, 67,  0],
#        [58, 59,  0],
#        [58, 60,  3],
#        [58, 61,  1],
#        [58, 67,  0],
#        [58, 58,  0],
#        [58, 58,  3],
#        [58, 61,  2],
#        [59, 62, 35],
#        [59, 60,  0],
#        [59, 63,  0],
#        [59, 64,  1],
#        [59, 64,  4],
#        [59, 64,  0],
#        [59, 64,  7],
#        [59, 67,  3],
#        [60, 59, 17],
#        [60, 65,  0],
#        [60, 61,  1],
#        [60, 67,  2],
#        [60, 61, 25],
#        [60, 64,  0],
#        [61, 62,  5],
#        [61, 65,  0],
#        [61, 68,  1],
#        [61, 59,  0],
#        [61, 59,  0],
#        [61, 64,  0],
#        [61, 65,  8],
#        [61, 68,  0],
#        [61, 59,  0],
#        [62, 59, 13],
#        [62, 58,  0],
#        [62, 65, 19],
#        [62, 62,  6],
#        [62, 66,  0],
#        [62, 66,  0],
#        [62, 58,  0],
#        [63, 60,  1],
#        [63, 61,  0],
#        [63, 62,  0],
#        [63, 63,  0],
#        [63, 63,  0],
#        [63, 66,  0],
#        [63, 61,  9],
#        [63, 61, 28],
#        [64, 58,  0],
#        [64, 65, 22],
#        [64, 66,  0],
#        [64, 61,  0],
#        [64, 68,  0],
#        [65, 58,  0],
#        [65, 61,  2],
#        [65, 62, 22],
#        [65, 66, 15],
#        [65, 58,  0],
#        [65, 64,  0],
#        [65, 67,  0],
#        [65, 59,  2],
#        [65, 64,  0],
#        [65, 67,  1],
#        [66, 58,  0],
#        [66, 61, 13],
#        [66, 58,  0],
#        [66, 58,  1],
#        [66, 68,  0],
#        [67, 64,  8],
#        [67, 63,  1],
#        [67, 66,  0],
#        [67, 66,  0],
#        [67, 61,  0],
#        [67, 65,  0],
#        [68, 67,  0],
#        [68, 68,  0],
#        [69, 67,  8],
#        [69, 60,  0],
#        [69, 65,  0],
#        [69, 66,  0],
#        [70, 58,  0],
#        [70, 58,  4],
#        [70, 66, 14],
#        [70, 67,  0],
#        [70, 68,  0],
#        [70, 59,  8],
#        [70, 63,  0],
#        [71, 68,  2],
#        [72, 63,  0],
#        [72, 58,  0],
#        [72, 64,  0],
#        [72, 67,  3],
#        [73, 62,  0],
#        [73, 68,  0],
#        [74, 65,  3],
#        [74, 63,  0],
#        [75, 62,  1],
#        [76, 67,  0],
#        [77, 65,  3],
#        [78, 65,  1],
#        [83, 58,  2]])

# %% [markdown]
# ### Scaling Features
#
# As you can see the data from various columns have various value ranges. Having the features in same range makes the algorithm to converge faster than using the features which are not scaled to be in same range.

# %%
from sklearn.preprocessing import MinMaxScaler
numcols=[0,1,2]
mms=MinMaxScaler()
X=mms.fit_transform(df[numcols])

# %%
X
# Out:
# array([[0.        , 0.54545455, 0.01923077],
#        [0.        , 0.36363636, 0.05769231],
#        [0.        , 0.63636364, 0.        ],
#        [0.01886792, 0.09090909, 0.03846154],
#        [0.01886792, 0.63636364, 0.07692308],
#        [0.05660377, 0.        , 0.19230769],
#        [0.05660377, 0.18181818, 0.        ],
#        [0.0754717 , 0.09090909, 0.        ],
#        [0.0754717 , 0.72727273, 0.17307692],
#        [0.0754717 , 0.        , 0.57692308],
#        [0.0754717 , 0.18181818, 0.01923077],
#        [0.0754717 , 0.27272727, 0.19230769],
#        [0.0754717 , 0.81818182, 0.13461538],
#        [0.0754717 , 0.18181818, 0.        ],
#        [0.09433962, 0.54545455, 0.25      ],
#        [0.09433962, 0.45454545, 0.        ],
#        [0.11320755, 0.18181818, 0.01923077],
#        [0.11320755, 1.        , 0.        ],
#        [0.13207547, 0.18181818, 0.        ],
#        [0.13207547, 0.45454545, 0.        ],
#        [0.13207547, 0.        , 0.        ],
#        [0.13207547, 0.09090909, 0.11538462],
#        [0.13207547, 0.18181818, 0.28846154],
#        [0.13207547, 0.45454545, 0.        ],
#        [0.1509434 , 1.        , 0.40384615],
#        [0.1509434 , 0.09090909, 0.03846154],
#        [0.1509434 , 0.18181818, 0.        ],
#        [0.1509434 , 0.18181818, 0.        ],
#        [0.1509434 , 0.36363636, 0.05769231],
#        [0.1509434 , 0.54545455, 0.01923077],
#        [0.1509434 , 0.72727273, 0.        ],
#        [0.1509434 , 0.72727273, 0.21153846],
#        [0.1509434 , 0.18181818, 0.01923077],
#        [0.1509434 , 0.81818182, 0.09615385],
#        [0.16981132, 0.72727273, 0.        ],
#        [0.16981132, 0.45454545, 0.        ],
#        [0.16981132, 0.81818182, 0.        ],
#        [0.16981132, 0.        , 0.        ],
#        [0.16981132, 0.09090909, 0.03846154],
#        [0.16981132, 0.45454545, 0.07692308],
#        [0.18867925, 0.        , 0.03846154],
#        [0.18867925, 0.        , 0.        ],
#        [0.18867925, 0.63636364, 0.        ],
#        [0.20754717, 0.18181818, 0.44230769],
#        [0.20754717, 0.54545455, 0.        ],
#        [0.20754717, 0.81818182, 0.        ],
#        [0.20754717, 0.        , 0.        ],
#        [0.20754717, 0.09090909, 0.15384615],
#        [0.20754717, 0.09090909, 0.        ],
#        [0.20754717, 0.54545455, 0.        ],
#        [0.20754717, 1.        , 0.15384615],
#        [0.20754717, 0.63636364, 0.        ],
#        [0.20754717, 0.63636364, 0.        ],
#        [0.22641509, 1.        , 0.01923077],
#        [0.22641509, 0.09090909, 0.        ],
#        [0.22641509, 0.        , 0.        ],
#        [0.22641509, 0.18181818, 0.01923077],
#        [0.22641509, 0.09090909, 0.03846154],
#        [0.22641509, 0.27272727, 0.07692308],
#        [0.22641509, 0.36363636, 0.38461538],
#        [0.22641509, 0.63636364, 0.        ],
#        [0.22641509, 0.45454545, 0.01923077],
#        [0.24528302, 0.        , 1.        ],
#        [0.24528302, 0.09090909, 0.03846154],
#        [0.24528302, 0.54545455, 0.        ],
#        [0.24528302, 0.54545455, 0.        ],
#        [0.67924528, 0.27272727, 0.25      ],
#        [0.67924528, 0.        , 0.        ],
#        [0.67924528, 0.        , 0.01923077],
#        [0.67924528, 0.90909091, 0.        ],
#        [0.69811321, 0.54545455, 0.15384615],
#        [0.69811321, 0.45454545, 0.01923077],
#        [0.69811321, 0.72727273, 0.        ],
#        [0.69811321, 0.72727273, 0.        ],
#        [0.69811321, 0.27272727, 0.        ],
#        [0.69811321, 0.63636364, 0.        ],
#        [0.71698113, 0.81818182, 0.        ],
#        [0.71698113, 0.90909091, 0.        ],
#        [0.73584906, 0.81818182, 0.15384615],
#        [0.73584906, 0.18181818, 0.        ],
#        [0.73584906, 0.63636364, 0.        ],
#        [0.73584906, 0.72727273, 0.        ],
#        [0.75471698, 0.        , 0.        ],
#        [0.75471698, 0.        , 0.07692308],
#        [0.75471698, 0.72727273, 0.26923077],
#        [0.75471698, 0.81818182, 0.        ],
#        [0.75471698, 0.90909091, 0.        ],
#        [0.75471698, 0.09090909, 0.15384615],
#        [0.75471698, 0.45454545, 0.        ],
#        [0.77358491, 0.90909091, 0.03846154],
#        [0.79245283, 0.45454545, 0.        ],
#        [0.79245283, 0.        , 0.        ],
#        [0.79245283, 0.54545455, 0.        ],
#        [0.79245283, 0.81818182, 0.05769231],
#        [0.81132075, 0.36363636, 0.        ],
#        [0.81132075, 0.90909091, 0.        ],
#        [0.83018868, 0.63636364, 0.05769231],
#        [0.83018868, 0.45454545, 0.        ],
#        [0.8490566 , 0.36363636, 0.01923077],
#        [0.86792453, 0.81818182, 0.        ],
#        [0.88679245, 0.63636364, 0.05769231],
#        [0.90566038, 0.63636364, 0.01923077],
#        [1.        , 0.        , 0.03846154]])

# %% [markdown]
# ### Splitting the data
#
# We split the data set into two parts: one for train and the other for test.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (214, 3) (214,)
# (92, 3) (92,)

# %% [markdown]
# We add one column consisting of ones.

# %%
n_train=len(y_train)
new_col=np.ones((n_train,1))
X_train_modified=np.append(X_train,new_col,1)

# %%
X_train_modified
# Out:
# array([[0.41509434, 0.90909091, 0.        , 1.        ],
#        [0.45283019, 0.18181818, 0.05769231, 1.        ],
#        [0.45283019, 0.18181818, 0.21153846, 1.        ],
#        [0.62264151, 0.72727273, 0.        , 1.        ],
#        [0.28301887, 0.81818182, 0.        , 1.        ],
#        [0.62264151, 0.27272727, 0.        , 1.        ],
#        [0.35849057, 0.81818182, 0.01923077, 1.        ],
#        [0.22641509, 0.27272727, 0.07692308, 1.        ],
#        [0.49056604, 0.63636364, 0.17307692, 1.        ],
#        [0.1509434 , 0.81818182, 0.09615385, 1.        ],
#        [0.33962264, 0.        , 0.21153846, 1.        ],
#        [0.50943396, 0.54545455, 0.01923077, 1.        ],
#        [0.58490566, 0.63636364, 0.15384615, 1.        ],
#        [0.58490566, 0.90909091, 0.        , 1.        ],
#        [0.35849057, 0.45454545, 0.        , 1.        ],
#        [0.16981132, 0.45454545, 0.07692308, 1.        ],
#        [0.20754717, 1.        , 0.15384615, 1.        ],
#        [0.43396226, 0.63636364, 0.23076923, 1.        ],
#        [0.37735849, 0.09090909, 0.03846154, 1.        ],
#        [0.54716981, 0.54545455, 0.13461538, 1.        ],
#        [0.0754717 , 0.09090909, 0.        , 1.        ],
#        [0.32075472, 0.45454545, 0.11538462, 1.        ],
#        [0.28301887, 0.09090909, 0.26923077, 1.        ],
#        [0.24528302, 0.45454545, 0.03846154, 1.        ],
#        [0.20754717, 0.63636364, 0.        , 1.        ],
#        [0.54716981, 0.36363636, 0.67307692, 1.        ],
#        [0.56603774, 0.63636364, 0.        , 1.        ],
#        [0.35849057, 0.36363636, 0.        , 1.        ],
#        [0.1509434 , 0.72727273, 0.21153846, 1.        ],
#        [0.66037736, 0.36363636, 0.42307692, 1.        ],
#        [0.0754717 , 0.18181818, 0.        , 1.        ],
#        [0.90566038, 0.63636364, 0.01923077, 1.        ],
#        [0.41509434, 0.27272727, 0.        , 1.        ],
#        [0.30188679, 0.        , 0.03846154, 1.        ],
#        [0.79245283, 0.45454545, 0.        , 1.        ],
#        [0.56603774, 0.09090909, 0.32692308, 1.        ],
#        [0.32075472, 0.90909091, 0.07692308, 1.        ],
#        [0.13207547, 0.09090909, 0.11538462, 1.        ],
#        [0.30188679, 0.36363636, 0.        , 1.        ],
#        [0.8490566 , 0.36363636, 0.01923077, 1.        ],
#        [0.05660377, 0.        , 0.19230769, 1.        ],
#        [0.43396226, 0.18181818, 0.01923077, 1.        ],
#        [0.28301887, 0.63636364, 0.11538462, 1.        ],
#        [0.01886792, 0.63636364, 0.07692308, 1.        ],
#        [0.75471698, 0.        , 0.        , 1.        ],
#        [0.33962264, 0.36363636, 0.03846154, 1.        ],
#        [0.32075472, 0.72727273, 0.        , 1.        ],
#        [0.47169811, 0.72727273, 0.34615385, 1.        ],
#        [0.09433962, 0.54545455, 0.25      , 1.        ],
#        [0.39622642, 0.09090909, 0.25      , 1.        ]])

# %%
n_test=len(y_test)
new_col=np.ones((n_test,1))
X_test_modified=np.append(X_test,new_col,1)

# %% [markdown]
# Define the function $\sigma(x) = \dfrac {e^x}{e^x+1}= \dfrac 1 {1+e^{-x}}$.

# %%
#def sigmoid(x):    
#    return the function

# %% [markdown]
# Define the error function
# $$ E (\mathbf{w}) = - \frac 1 N \sum_{n=1}^N \{ t_n \ln y_n + (1-t_n) \ln (1-y_n)\},  $$
# where $y_n=\sigma(w_1 x_{n1}+ w_2 x_{n2} + \cdots + w_k x_{nk}+w_{k+1} )$. This function will be obtained in Logistic Regression.

# %%
#def Er(w):
#    yn=
#    return ???

# %% [markdown]
# Define the gradient of $E$.

# %%
#def gradE(w):
#    return the function

# %% [markdown]
# Set the initial values.

# %%
#w=[[?],[?],[?],[?]]
#eta=
#iter_num=

# %% [markdown]
# Run a loop for gradient descent.

# %%
#for i in range(iter_num):
#

# %%
print(w)
# Out:
# [[-1.17834346]
#  [ 0.41255568]
#  [-3.2720623 ]
#  [ 1.64111766]]

# %% [markdown]
# We compute the accuracy of the trained model.

# %%
y_pred=(sigmoid(X_test_modified@w).round()).reshape([1,n_test])
y_test=y_test%2
print("Train Accuracy:", sum(y_test==y_pred[0])*100/n_test,"%")
# Out:
# [[ 0.06061997]
#  [ 0.01476229]
#  [-0.39835658]
#  [ 1.00630046]]
# Train Accuracy: 72.82608695652173 %
